# %% [markdown]
# ## PIPELINE PROJECT JPdA

# %% [markdown]
# ### En este proyecto vamos a comparar la contaminación de los paises con la mortalidad por contaminación de cada país.

# %% [markdown]
# #### Importamos las librerías necesarias:

# %%
import json
from requests import api
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### Para facilitar el estudio hemos creado un dataset reducido (results.min.csv)

# %%
plt.figure(figsize=(15, 15))
dataset =  pd.read_csv("./Data/result.min.csv")
print(dataset.pollution)
sns.barplot(x="country", y="deaths", data=dataset)
# Out:
# 0     0.2450
# 1     1.1800
# 2     1.5700
# 3    21.7000
# 4     4.6000
# 5     1.7600
# 6     5.9000
# 7     3.8200
# 8     0.0461
# Name: pollution, dtype: float64
# <AxesSubplot:xlabel='country', ylabel='deaths'>

# %%
plt.figure(figsize=(15, 15))
sns.barplot(x="country", y="pollution", data=dataset)
# Out:
# <AxesSubplot:xlabel='country', ylabel='pollution'>

# %% [markdown]
# ### Como se puede apreciar en las gráficas, no existe una relación de dependencia. La contaminación que produce cada país no es proporcional al número de muertes que hay por contaminación en dicho país. Esto se ve reflejado, por ejemplo, en Emiratos Arabes Unidos, siendo el país que más contamina es el que menos mortalidad por contaminación padece.
